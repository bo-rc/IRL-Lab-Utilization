# %% [markdown]
# # load python modules

# %%
from ScheduleReport import Report as rp

# %% [markdown]
# ## to List all project information

# %%
print(rp.PI_dict)
# Out:
# defaultdict(None, {'Lui Sha': PI: Lui Sha  CS CS,CSL 2016-08-100-02, 'Romit Roy Choudhury': PI: Romit Roy Choudhury  ECE ECE,CSL 2017-06-100-01,2016-08-100-01,2017-02-100-01, 'Sayan Mitra': PI: Sayan Mitra  ECE ECE,CSL 2016-06-103-01,2017-03-103-01, 'Girish Krishnan': PI: Girish Krishnan  ISE ISE,CSL 2017-03-106-01, 'Seth Hutchinson': PI: Seth Hutchinson  ECE ECE,CSL 2016-10-103-02,2016-10-103-01, 'Grace Gao': PI: Grace Gao  AE AE,CSL 2016-11-103-01, 'Minh Do': PI: Minh Do  ECE ECE,CSL 2016-11-103-02, 'Timothy Bretl': PI: Timothy Bretl  AE AE,CSL 2017-02-103-02, 'Michael Selig': PI: Michael Selig  AE AE 2017-02-102-01, 'Hae-Won Park': PI: Hae-Won Park  ME ME,CSL 2017-02-101-01, 'Aimy Wissa': PI: Aimy Wissa  ME ME 2017-04-101-01, 'Philip Ansell': PI: Philip Ansell  AE AE 2017-01-102-01, 'Girish Chowdhary': PI: Girish Chowdhary  ABE ABE,CSL 2016-11-105-01,2016-10-105-01, 'Amy LaViers': PI: Amy LaViers  ME ME 2016-12-101-01, 'Naira Hovakimyan': PI: Naira Hovakimyan  ME ME,AE,CSL 2016-08-101-01, 'Paul G Kwiat': PI: Paul G Kwiat  PHYS PHYS,ECE 2016-08-104-01,2018-01-104-01, 'Dan Work': PI: Dan Work  CEE CEE,CSL 2017-06-107-01, 'Sibin Mohan': PI: Sibin Mohan  CS CS,CSL 2017-12-100-01, 'Geir Dullerud': PI: Geir Dullerud  ME ME,CS,CSL 2017-09-101-01})

# %% [markdown]
# ## to show information about a particular PI

# %%
rp.PI_dict['Naira Hovakimyan']

# %% [markdown]
# ### all PI entries are dictionaries so you can check a particular field, for example:

# %% [markdown]
# * departments:

# %%
rp.PI_dict['Sayan Mitra'].dept

# %% [markdown]
# * appointments:

# %%
rp.PI_dict['Naira Hovakimyan'].app

# %% [markdown]
# * projects:

# %%
rp.PI_dict['Naira Hovakimyan'].proj

# %% [markdown]
# # to generate reports

# %% [markdown]
# #### There are functions to generate reports. All functions have default arguments so if you omit arguments for that function, the default arguments will be used.
#
#
# #### Results will appear in the `IRL-Lab-Utilization/output folder`

# %% [markdown]
# * `report_month()` function generates report for a month:

# %%
rp.report_month(2017,7)

# %%
for i in [1,2]:
    rp.report_month(2018, i)
# Out:
# 2018-01-01 to 2018-02-01
# 2018-02-01 to 2018-03-01

# %%
for i in [7, 8, 9, 10, 11, 12]:
    rp.report_month(2016, i)
# Out:
# 2016-07-01 to 2016-08-01
# 2016-08-01 to 2016-09-01
# 2016-09-01 to 2016-10-01
# 2016-10-01 to 2016-11-01
# 2016-11-01 to 2016-12-01
# 2016-12-01 to 2017-01-01

# %% [markdown]
# * report_range() function generates report for a range defined by dates:

# %%
rp.report_range(2017,2,15, 2018,2,14)
# Out:
# 2017-02-15 to 2018-02-14

# %% [markdown]
# * if the figure has cluttered labels, you may want to generate a wide figure by setting `wide_figure = True`, e.g.:

# %%
rp.report_range(2017,2,15, 2018,2,14, wide_figure=True)
# Out:
# 2017-02-15 to 2018-02-14

# %% [markdown]
# * `get_days_record()` generates a .txt file about usage per day list from a start date to today. You may omit the start date to use the default start date which is 2016-08-01

# %%
rp.get_days_record() # from 2016-08-01 to today

# %%
rp.get_days_record(2017,9,1) # from 2017-09-01 to today
